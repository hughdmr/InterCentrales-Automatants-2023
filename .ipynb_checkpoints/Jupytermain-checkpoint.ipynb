# %%
import numpy as np
import torch

# %%
inputs = torch.randn(50,16,50,100)

# %%
class ResNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(16,32,kernel_size=3,padding=1)
        self.conv2 = torch.nn.Conv2d(32,64,kernel_size=3,padding=1)
        self.conv3 = torch.nn.Conv2d(64,128,kernel_size=3,padding=1)
        self.conv4 = torch.nn.Conv2d(128,64,kernel_size=3,padding=1)
        
        self.convretro1 = torch.nn.Conv2d(16,64,kernel_size=1)
        self.convretro2 = torch.nn.Conv2d(32,128,kernel_size=1)
    
    def forward(self,inputs):
        o1 = self.conv1(inputs)
        o2 = self.conv2(o1)
        
        o3 = self.conv3(o2+self.convretro1(inputs))
        print(o2.shape, self.convretro1(inputs).shape)
        o4 = self.conv4(o3+self.convretro2(o1))
        

        return o4

# %%
model = ResNet()

# %%
output = model.forward(inputs)
# Out:
# torch.Size([50, 64, 50, 100]) torch.Size([50, 64, 50, 100])

# %%
from skimage import io
from torch.utils.data import Dataset, DataLoader
import os, csv
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
csv_path = "C:\\Users\\Hugues\\Documents\\SCOLARITE\\CS\\AUTOMATANTS\\InterCentrales\\assignment-2023\\image_series.csv"
mode = "train"
batch_size = 20
shuffle_data = 'True'

# %%
class BaselineDataset(Dataset):
    """
    Baseline pytorch dataset for the competition data.
    Note that it does not leverage mask information, augment the data nor normalise it in any way.
    """

    def __init__(self):
        data_directory = os.path.dirname(os.path.abspath(csv_path))
        print(data_directory)
        self.s1_folder = os.path.join(data_directory, "s1")
        self.s2_folder = os.path.join(data_directory, "s2")
        self.masks_folder = os.path.join(data_directory, "s2-mask")

        with open(csv_path) as path_list:
            self.data_paths = [[os.path.basename(path) for path in row] for row in csv.reader(path_list, delimiter=",")][1:]
            

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, index: int) -> dict:
        """ Reads a sample from the disk and returns it in the form of a dictionary. """

        paths = self.data_paths[index]
        s1 = [load_image(os.path.join(self.s1_folder, i)) for i in paths]
        if mode == "infer":
            s2 = [load_image(os.path.join(self.s2_folder, i)) for i in paths[:-1]]
            masks = [load_image(os.path.join(self.masks_folder, i)) for i in paths[:-1]]
            label = None
            label_mask = None
        else:
            s2 = [load_image(os.path.join(self.s2_folder, i)) for i in paths]
            masks = [load_image(os.path.join(self.masks_folder, i)) for i in paths]
            label = s2.pop(-1)
            label_mask = masks.pop(-1)

        return {
            "paths": paths,
            "s1": torch.from_numpy(np.concatenate(s1, axis=-1, dtype='float32')),
            "s2": torch.from_numpy(np.concatenate(s2, axis=-1,dtype='float32')),
            "masks": torch.from_numpy(np.concatenate(masks, axis=-1,dtype='float32')),
            "label": torch.from_numpy(label) if label is not None else [0],
            "label_mask": torch.from_numpy(label_mask) if label_mask is not None else [0],
        }


def get_loader():
    """ Get a loader for the data for batching and shuffling. """
    dataset = BaselineDataset()
    return DataLoader(dataset,
                      batch_size=batch_size,
                      shuffle=shuffle_data)


def load_image(path: str) -> np.ndarray:
    """ Loads TIFF images and returns a numpy array with shape (256, 256, channels). """
    image = io.imread(path)
    if len(image.shape) == 2:
        image = np.expand_dims(image, axis=-1)
    return image

# %%
get_load = get_loader()
# Out:
# C:\Users\Hugues\Documents\SCOLARITE\CS\AUTOMATANTS\InterCentrales\assignment-2023

# %%
fig = plt.figure(figsize=(10,7))
rows = 2
columns = 2
fig.add_subplot(rows,columns,1)
a=iter(get_load)
images = next(a)
plt.imshow(images['s2'][0,:,:,0])
fig.add_subplot(rows,columns,2)
plt.imshow(images['s2'][0,:,:,1])
fig.add_subplot(rows,columns,3)
plt.imshow(images['label'][0,:,:,0])

# %%
L=[0 for i in range(12)]
length_loader=len(get_load)

n=0
for i in get_load:
    image=next(iter(get_load))
    mask_image=image['masks']
    arr=np.array(mask_image[0,:,:,1])
    siz=arr.size
    new_deno=n+siz
    print(new_deno)
    counter_nonzero=0
    
    for j in range(1,12):
        countfj_nonzero=np.count_nonzero(arr== j)
        print(countfj_nonzero)
        counter_nonzero+=countfj_nonzero
        L[j]+=countfj_nonzero*((n+1)/(new_deno))
    
    L[0]+=(siz - counter_nonzero)*(n/(new_deno))
    n=new_deno
    print(L)
   
        
print(L)
# Out:
# 65536
# 0
# 76
# 0
# 62080
# 3352
# 0
# 20
# 4
# 4
# 0
# 0
# [0.0, 0.0, 0.00115966796875, 0.0, 0.947265625, 0.0511474609375, 0.0, 0.00030517578125, 6.103515625e-05, 6.103515625e-05, 0.0, 0.0]
# 131072
# 0
# 918
# 0
# 32350
# 27630
# 0
# 4398
# 168
# 72
# 0
# 0
# [0.0, 0.0, 459.00816345214844, 0.0, 16176.194076538086, 13815.261947631836, 0.0, 2199.0338592529297, 84.0013427734375, 36.0006103515625, 0.0, 0.0]
# 196608
# 0
# 136
# 0
# 19498
# 45814
# 0
# 64
# 0
# 24
# 0
# 0
# [0.0, 0.0, 549.6755218505859, 0.0, 29174.959915161133, 44358.16163635254, 0.0, 2241.7008514404297, 84.0013427734375, 52.000732421875, 0.0, 0.0]
# 262144
# 0
# 408
# 0
# 64082
# 862
# 88
# 96
# 0
# 0
# 0
# 0
# [0.0, 0.0, 855.6770782470703, 0.0, 77236.70436859131, 45004.66492462158, 66.00033569335938, 2313.701217651367, 84.0013427734375, 52.000732421875, 0.0, 0.0]
# 327680
# 0
# 316
# 0
# 18156
# 46864
# 116
# 84
# 0
# 0
# 0
# 0
# [0.0, 0.0, 1108.478042602539, 0.0, 91761.55977630615, 82496.0079421997, 158.80068969726562, 2380.9014739990234, 84.0013427734375, 52.000732421875, 0.0, 0.0]
# 393216
# 0
# 86
# 0
# 31153
# 34205
# 4
# 68
# 12
# 8
# 0
# 0
# [0.0, 0.0, 1180.1449279785156, 0.0, 117722.47233581543, 111000.26159667969, 162.134033203125, 2437.568313598633, 94.00137329101562, 58.66741943359375, 0.0, 0.0]
# 458752
# 0
# 359
# 0
# 40928
# 23309
# 202
# 198
# 8
# 20
# 512
# 0
# [0.0, 0.0, 1487.8599962506976, 0.0, 152803.7044089181, 130979.45526341029, 335.27733067103793, 2607.283030918666, 100.85853358677456, 75.81032017299107, 438.85825892857144, 0.0]
# 524288
# 0
# 12
# 0
# 29238
# 36262
# 0
# 24
# 0
# 0
# 0
# 0
# [0.0, 0.0, 1498.3600191388812, 0.0, 178387.01017597743, 162708.7744276864, 335.27733067103793, 2628.2830766950333, 100.85853358677456, 75.81032017299107, 438.85825892857144, 0.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[160], line 6
#       4 n=0
#       5 for i in get_load:
# ----> 6     image=next(iter(get_load))
#       7     mask_image=image['masks']
#       8     arr=np.array(mask_image[0,:,:,1])
#
# File ~\miniconda3\lib\site-packages\torch\utils\data\dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\miniconda3\lib\site-packages\torch\utils\data\dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\miniconda3\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~\miniconda3\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[106], line 32, in BaselineDataset.__getitem__(self, index)
#      30     label_mask = None
#      31 else:
# ---> 32     s2 = [load_image(os.path.join(self.s2_folder, i)) for i in paths]
#      33     masks = [load_image(os.path.join(self.masks_folder, i)) for i in paths]
#      34     label = s2.pop(-1)
#
# Cell In[106], line 32, in <listcomp>(.0)
#      30     label_mask = None
#      31 else:
# ---> 32     s2 = [load_image(os.path.join(self.s2_folder, i)) for i in paths]
#      33     masks = [load_image(os.path.join(self.masks_folder, i)) for i in paths]
#      34     label = s2.pop(-1)
#
# Cell In[106], line 57, in load_image(path)
#      55 def load_image(path: str) -> np.ndarray:
#      56     """ Loads TIFF images and returns a numpy array with shape (256, 256, channels). """
# ---> 57     image = io.imread(path)
#      58     if len(image.shape) == 2:
#      59         image = np.expand_dims(image, axis=-1)
#
# File ~\miniconda3\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~\miniconda3\lib\site-packages\skimage\io\manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\skimage\io\_plugins\tifffile_plugin.py:74, in imread(fname, **kwargs)
#      71 if 'img_num' in kwargs:
#      72     kwargs['key'] = kwargs.pop('img_num')
# ---> 74 return tifffile_imread(fname, **kwargs)
#
# File ~\miniconda3\lib\site-packages\tifffile\tifffile.py:1053, in imread(files, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1048     files = files[0]
#    1050 if isinstance(files, str) or not isinstance(
#    1051     files, collections.abc.Sequence
#    1052 ):
# -> 1053     with TiffFile(
#    1054         files,
#    1055         mode=mode,
#    1056         name=name,
#    1057         offset=offset,
#    1058         size=size,
#    1059         omexml=omexml,
#    1060         _multifile=_multifile,
#    1061         _useframes=_useframes,
#    1062         **is_flags,
#    1063     ) as tif:
#    1064         if aszarr:
#    1065             assert key is None or isinstance(key, int)
#
# File ~\miniconda3\lib\site-packages\tifffile\tifffile.py:3965, in TiffFile.__init__(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    3962 if mode not in (None, 'r', 'r+', 'rb', 'r+b'):
#    3963     raise ValueError(f'invalid mode {mode!r}')
# -> 3965 fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    3966 self._fh = fh
#    3967 self._multifile = True if _multifile is None else bool(_multifile)
#
# File ~\miniconda3\lib\site-packages\tifffile\tifffile.py:13845, in FileHandle.__init__(self, file, mode, name, offset, size)
#   13843 self._close = True
#   13844 self._lock = NullContext()
# > 13845 self.open()
#   13846 assert self._fh is not None
#
# File ~\miniconda3\lib\site-packages\tifffile\tifffile.py:13860, in FileHandle.open(self)
#   13858 self._file = os.path.realpath(self._file)
#   13859 self._dir, self._name = os.path.split(self._file)
# > 13860 self._fh = open(self._file, self._mode)  # type: ignore
#   13861 self._close = True
#   13862 if self._offset < 0:
#
# KeyboardInterrupt:
